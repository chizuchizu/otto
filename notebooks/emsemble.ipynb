# %%
import pandas as pd
import numpy as np

# %%
a = pd.read_csv("../data/07_model_output/2020-02-28 18:01:52.850503.csv")  # LGBM
b = pd.read_csv("../data/07_model_output/2020-03-06 19:56:17.829530.csv")  # NN
cc = pd.read_csv("../data/07_model_output/2020-03-07 09:21:32.668041.csv")  # NN
d = pd.read_csv("../data/07_model_output/2020-03-06 17:29:43.269326.csv")  # LGBM

# %%
knn = np.load("../data/04_features/oof.npy")
knn.shape
# Out:
# (206246, 9)

# %%
a.shape
# Out:
# (144368, 10)

# %%
knn_pred = knn[knn.shape[0] - a.shape[0]:, :]

pred_you = a.copy()

pred_you.iloc[:, 1:] = knn_pred

# pd.DataFrame(knn_pred).to_csv("../data/07_model_output/knn_model.csv", index=None)
pred_you.to_csv("../data/07_model_output/knn_model.csv", index=None)

# %%
a.head()
# Out:
#    id   Class_1   Class_2   Class_3       Class_4       Class_5   Class_6  \
# 0   1  0.000101  0.137626  0.151911  7.076834e-01  2.979155e-08  0.000098
# 1   2  0.000633  0.003088  0.000421  1.824725e-04  6.750905e-06  0.661628
# 2   3  0.000002  0.000004  0.000008  7.763564e-07  8.111064e-10  0.999629
# 3   4  0.000045  0.616665  0.379962  2.818116e-03  4.779739e-08  0.000030
# 4   5  0.089348  0.000086  0.000300  9.025851e-05  2.469828e-07  0.003541
#
#     Class_7   Class_8   Class_9
# 0  0.002492  0.000073  0.000015
# 1  0.000667  0.332462  0.000911
# 2  0.000005  0.000349  0.000001
# 3  0.000034  0.000030  0.000415
# 4  0.009342  0.097415  0.799878

# %%
b.head()
# Out:
#    id   Class_1   Class_2   Class_3   Class_4       Class_5   Class_6  \
# 0   1  0.000147  0.444794  0.235556  0.317281  2.042461e-05  0.000142
# 1   2  0.000111  0.000044  0.000057  0.000007  2.918467e-06  0.006351
# 2   3  0.000021  0.000022  0.000008  0.000024  8.959117e-09  0.999714
# 3   4  0.000078  0.664058  0.316237  0.018924  5.615304e-05  0.000024
# 4   5  0.620661  0.000040  0.000016  0.000009  7.892614e-06  0.000779
#
#     Class_7   Class_8   Class_9
# 0  0.001866  0.000047  0.000147
# 1  0.000038  0.992516  0.000873
# 2  0.000036  0.000124  0.000050
# 3  0.000467  0.000061  0.000095
# 4  0.000413  0.014388  0.363686

# %%
c = a * 0.25 + b * 0.3 + cc * 0.2 + d * 0.2 + pred_you * 0.05
c["id"] = a["id"]

# %%
c.to_csv("../data/07_model_output/emsemble_nn_5_lgbm_5_knn_1_5kinds.csv", index=False)

# %%
c
# Out:
#             id   Class_1   Class_2   Class_3   Class_4       Class_5  \
# 0            1  0.000231  0.324602  0.204341  0.386403  1.226456e-05
# 1            2  0.000220  0.002278  0.000817  0.000260  4.919421e-05
# 2            3  0.000009  0.000012  0.000022  0.000012  2.522428e-08
# 3            4  0.000151  0.562329  0.345417  0.011129  2.189414e-05
# 4            5  0.333912  0.000892  0.000756  0.000099  2.641554e-04
# ...        ...       ...       ...       ...       ...           ...
# 144363  144364  0.332294  0.009321  0.003360  0.004359  2.756048e-04
# 144364  144365  0.000439  0.292318  0.492711  0.072955  2.280418e-05
# 144365  144366  0.000268  0.524124  0.273478  0.116364  4.841485e-05
# 144366  144367  0.000071  0.310309  0.033014  0.575687  2.655141e-05
# 144367  144368  0.000297  0.445477  0.419401  0.035240  2.952679e-05
#
#          Class_6   Class_7   Class_8   Class_9
# 0       0.000208  0.004051  0.000055  0.000096
# ...
